# %%
import pandas as pd

data = pd.read_csv(data_path + "sentiment_4.csv")
df_sample = data.drop(['wav_id', '1번 감정세기', '2번 감정세기', '3번 감정세기', '4번감정세기', '5번 감정세기'], axis=1)
df_sample
# Out:
#                                발화문     상황    1번 감정    2번 감정    3번 감정    4번 감정  \
# 0                     청소 네가 대신 해 줘  anger  Neutral    Angry  Neutral  Neutral
# 1                 둘 다 청소 하기 싫어 귀찮아  anger  Neutral    Angry  Neutral  Neutral
# 2                    둘 다 하기 싫어서 화내  anger    Angry    Angry  Neutral    Angry
# 3                       그럼 방세는 어떡해  anger  Sadness  Sadness  Sadness  Sadness
# 4       권택인 줄 알았는데 그런 사람이 생겼나 보더라고    sad  Sadness  Sadness  Sadness  Sadness
# ...                            ...    ...      ...      ...      ...      ...
# 13907                 아니 아직 말 못 했어    sad  Sadness  Sadness  Sadness  Sadness
# 13908  안 먹었는데 입맛도 없어서 안 먹어도 될 거 같아    sad  Sadness  Sadness  Sadness  Sadness
# 13909              룸메와 너무 자주 싸우게 돼  anger    Angry    Angry    Angry    Angry
# 13910               눈매가 존스 안 해 가지고  anger    Angry    Angry    Angry    Angry
# 13911               얘기해 봤는데 안 고쳐 줘  anger    Angry    Angry    Angry    Angry
#
#          5번 감정
# 0        Angry
# ...
